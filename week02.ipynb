# %% [markdown]
# <a href="https://colab.research.google.com/github/maulidyaafriani/PCVK_Genap_2026/blob/main/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')


import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

from google.colab import files
uploaded = files.upload()

# Corrected line: assign the image loaded to the 'img' variable
img = cv.imread('ktm (1).jpeg')
cv2_imshow(img)

print("Resolusi gambar: ", img.shape[1], " x ", img.shape[0])
img = cv.imread('ktm.jpeg')
plt.imshow(img) #format warna BGR

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab.patches import cv2_imshow

print("Shape gambar:", img.shape)
print("Resolusi:", img.shape[1], "x", img.shape[0])
print("Tipe data:", img.dtype)

cv2_imshow(img)

plt.imshow(img)
plt.axis('off')
plt.show()

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

print("Shape grayscale:", gray.shape)

plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

resize_img = cv2.resize(img, (640, 447))

print("Ukuran sebelum:", img.shape)
print("Ukuran sesudah:", resize_img.shape)

cv2_imshow(resize_img)

imgFlip = cv2.flip(resize_img, 1)

plt.imshow(cv2.cvtColor(imgFlip, cv2.COLOR_BGR2RGB))
plt.show()

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

plt.imshow(canvas)
plt.show()

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

cv2_imshow(canvas)

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

cv2.rectangle(canvas, (100, 100), (300, 250), (0, 255, 0), 3)

cv2_imshow(canvas)

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

cv2.rectangle(canvas, (100, 100), (300, 250), (0, 255, 0), 3)
cv2.circle(canvas, (450, 200), 80, (255, 0, 0), 3)

cv2_imshow(canvas)

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

cv2.rectangle(canvas, (100, 100), (300, 250), (0, 255, 0), 3)
cv2.circle(canvas, (450, 200), 80, (255, 0, 0), 3)
cv2.line(canvas, (100, 350), (600, 350), (0, 0, 255), 3)

cv2_imshow(canvas)

canvas = np.zeros((500, 700, 3), dtype=np.uint8)

cv2.rectangle(canvas, (100, 100), (300, 250), (0, 255, 0), 3)
cv2.circle(canvas, (450, 200), 80, (255, 0, 0), 3)
cv2.line(canvas, (100, 350), (600, 350), (0, 0, 255), 3)

cv2.putText(
    canvas,
    "MAULIDYA AFRIANI",
    (150, 430),
    cv2.FONT_HERSHEY_SIMPLEX,
    1,
    (255, 255, 255),
    2
)

cv2_imshow(canvas)

canvas2 = np.zeros((500, 700, 3), dtype=np.uint8)

pts = np.array([
    [100, 100],
    [200, 50],
    [350, 150],
    [300, 300],
    [150, 250]
], np.int32)

pts = pts.reshape((-1, 1, 2))

cv2.polylines(canvas2, [pts], True, (0, 255, 255), 3)

cv2_imshow(canvas2)




canvas = np.zeros((520, 520, 3), dtype=np.uint8)


cv2.rectangle(canvas, (40, 20), (190, 130), (0, 255, 0), 4)


cv2.circle(canvas, (350, 95), 60, (255, 0, 0), 4)


cv2.line(canvas, (40, 205), (480, 205), (0, 0, 255), 4)


cv2.putText(
    canvas,
    "PCVK is fun!",
    (80, 270),
    cv2.FONT_HERSHEY_SIMPLEX,
    1,
    (255, 255, 255),
    2
)

cv2.rectangle(canvas, (250, 250), (350, 350), (0, 0, 255), 7)


cv2.circle(canvas, (400, 400), 45, (0, 255, 0), -1)


pts = np.array([
    [40, 395],
    [120, 355],
    [230, 430],
    [190, 515],
    [80, 480]
], np.int32)

pts = pts.reshape((-1, 1, 2))

cv2.polylines(canvas, [pts], True, (0, 255, 255), 4)

cv2_imshow(canvas)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-3c40a025-85e8-48d9-adc0-94c413ac28d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c40a025-85e8-48d9-adc0-94c413ac28d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
